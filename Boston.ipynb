# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib as plt
from pylab import rcParams
import seaborn as sb

# %matplotlib inline
rcParams['figure.figsize']= 10, 10
sb.set_style('whitegrid')

# %%
boston_file='C:/Users/shank/Desktop/Data Analytics/Boston.csv'
boston=pd.read_csv(boston_file)

# %%
boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
boston.shape
# Out:
# (506, 15)

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
boston.plot(kind='scatter', x='medv', y='rm', c=['blue'], s=150)

# %%
from matplotlib import pyplot as plt
plt.scatter(boston['medv'], boston['rm'])
plt.xlabel('medv')
plt.ylabel('rm')
#plt.xlim(0,60)
#plt.ylim(0,60)
plt.show()

# %%
from matplotlib import pyplot as plt
plt.scatter(boston['lstat'], boston['medv'])
plt.xlabel('lstat')
plt.ylabel('medv')
#plt.xlim(0,60)
#plt.ylim(0,60)
plt.show()

# %%
corr_mat=boston.corr()
corr_mat['crim'].sort_values()
# Out:
# medv         -0.388305
# black        -0.385064
# dis          -0.379670
# rm           -0.219247
# zn           -0.200469
# chas         -0.055892
# ptratio       0.289946
# age           0.352734
# indus         0.406583
# Unnamed: 0    0.407407
# nox           0.420972
# lstat         0.455621
# tax           0.582764
# rad           0.625505
# crim          1.000000
# Name: crim, dtype: float64

# %%
plt.scatter(boston['tax'], boston['crim'])
plt.xlabel('tax')
plt.ylabel('crim');

# %%
plt.style.use('ggplot')
sb.pairplot(boston)

# %%
corr_mat=boston.corr()
corr_mat['crim'].sort_values()
# Out:
# medv         -0.388305
# black        -0.385064
# dis          -0.379670
# rm           -0.219247
# zn           -0.200469
# chas         -0.055892
# ptratio       0.289946
# age           0.352734
# indus         0.406583
# Unnamed: 0    0.407407
# nox           0.420972
# lstat         0.455621
# tax           0.582764
# rad           0.625505
# crim          1.000000
# Name: crim, dtype: float64

# %%
boston.loc[boston['crim'].nlargest(5).index]
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 380         381  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24
# 418         419  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24
# 405         406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24
# 410         411  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24
# 414         415  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24
#
#      tax  ptratio   black  lstat  medv
# 380  666     20.2  396.90  17.21  10.4
# 418  666     20.2   16.45  20.62   8.8
# 405  666     20.2  384.97  22.98   5.0
# 410  666     20.2    2.60  10.11  15.0
# 414  666     20.2   88.27  36.98   7.0

# %%
boston.loc[boston['tax'].nlargest(5).index]
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 488         489  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4
# 489         490  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4
# 490         491  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4
# 491         492  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4
# 492         493  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4
#
#      tax  ptratio   black  lstat  medv
# 488  711     20.1  395.09  18.06  15.2
# 489  711     20.1  344.05  23.97   7.0
# 490  711     20.1  318.43  29.68   8.1
# 491  711     20.1  390.11  18.07  13.6
# 492  711     20.1  396.90  13.35  20.1

# %%
boston.loc[boston['ptratio'].nlargest(5).index]
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age      dis  rad  \
# 354         355  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4
# 355         356  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4
# 127         128  0.25915   0.0  21.89     0  0.624  5.693  96.0   1.7883    4
# 128         129  0.32543   0.0  21.89     0  0.624  6.431  98.8   1.8125    4
# 129         130  0.88125   0.0  21.89     0  0.624  5.637  94.7   1.9799    4
#
#      tax  ptratio   black  lstat  medv
# 354  334     22.0  382.80   8.05  18.2
# 355  334     22.0  376.04   5.57  20.6
# 127  437     21.2  392.11  17.19  16.2
# 128  437     21.2  396.90  15.39  18.0
# 129  437     21.2  396.90  18.34  14.3

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
boston_subset = boston[boston['chas']==1]
boston_subset.shape
# Out:
# (35, 15)

# %%
boston['ptratio'].median()
# Out:
# 19.05

# %%
boston['medv'].idxmin()
# Out:
# 398

# %%
a = boston.describe()
a.loc['range'] = a.loc['max'] - a.loc['min']
a.loc[398] = boston.loc[398]
a
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
# range  505.000000   88.969880  100.000000   27.280000    1.000000    0.486000
# 398    399.000000   38.351800    0.000000   18.100000    0.000000    0.693000
#
#                rm         age         dis         rad         tax     ptratio  \
# ...

# %%
boston.loc[boston['rm']>7].shape
# Out:
# (64, 15)

# %%
boston.loc[boston['rm']>8].shape
# Out:
# (13, 15)
